# %% [markdown]
# ### Import Dependencies

# %%
from pydantic import BaseModel, Field

from qdrant_client import QdrantClient
from qdrant_client.models import Prefetch, Filter, FieldCondition, MatchText, FusionQuery, Document


from langsmith import traceable, get_current_run_tree

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send, Command

from langchain_core.messages import AIMessage, ToolMessage, convert_to_openai_messages

from jinja2 import Template
from typing import Literal, Dict, Any, Annotated, List, Optional, Sequence
from IPython.display import Image, display
from operator import add
from openai import OpenAI

import openai

import random
import ast
import inspect
import instructor
import json

from utils.utils import get_tool_descriptions, format_ai_message

# %% [markdown]
# ### Define Retrieval Tool

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={"ls_provider": "openai", "ls_model_name": "text-embedding-3-small"}
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    current_run = get_current_run_tree()

    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens,
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retrieve_data(query, k=5):

    query_embedding = get_embedding(query)

    qdrant_client = QdrantClient(url="http://localhost:6333")

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-hybrid-search",
        prefetch=[
            Prefetch(
                query=query_embedding,
                using="text-embedding-3-small",
                limit=20
            ),
            Prefetch(
                query=Document(
                    text=query,
                    model="qdrant/bm25"
                ),
                using="bm25",
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


def get_formatted_context(query: str, top_k: int = 5) -> str:

    """Get the top k context, each representing an inventory item for a given query.
    
    Args:
        query: The query to get the top k context for
        top_k: The number of context chunks to retrieve, works best with 5 or more
    
    Returns:
        A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.
    """

    context = retrieve_data(query, top_k)
    formatted_context = process_context(context)

    return formatted_context

# %% [markdown]
# #### State and Pydantic Models for Structured Outputs

# %%
class ToolCall(BaseModel):
    name: str
    arguments: dict

class RAGUsedContext(BaseModel):
    id: str = Field(description="The ID of the item used to answer the question")
    description: str = Field(description="Short description of the item used to answer the question")
    
class AgentResponse(BaseModel):
    answer: str = Field(description="Answer to the question.")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question.")
    final_answer: bool = False
    tool_calls: List[ToolCall] = []

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    question_relevant: bool = False
    iteration: int = 0
    answer: str = ""
    available_tools: List[Dict[str, Any]] = []
    tool_calls: List[ToolCall] = []
    final_answer: bool = False
    references: Annotated[List[RAGUsedContext], add] = []

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def agent_node(state: State) -> dict:

   prompt_template =  """You are a shopping assistant that can answer questions about the products in stock.

You will be given a conversation history and a list of tools you can use to answer the latest query.

<Available tools>
{{ available_tools | tojson }}
</Available tools>

When making tool calls, use this exact format:
{
    "name": "tool_name",
    "arguments": {
        "parameter1": "value1",
        "parameter2": "value2",
    }
}

CRITICAL: All parameters must go inside the "arguments" object, not at the top level of the tool call.

Examples:
- Get formatted item context:
{
    "name": "get_formatted_item_context",
    "arguments": {
        "query": "Kool kids toys.",
        "top_k": 5
    }
}

CRITICAL RULES:
- If tool_calls has values, final_answer MUST be false
(You cannot call tools and exit the graph in the same response)
- If final_answer is true, tool_calls MUST be []
(You must wait for tool results before exiting the graph)
- If you need tool results before answering, set:
tool_calls=[...], final_answer=false
- After receiving tool results, you can then set:
tool_calls=[], final_answer=true
- Use names specificly provided in the available tools. Don't add any additional text to the names.

Instructions:
- You need to answer the question based on the outputs from the tools using the available tools only.
- Do not suggest the same tool call more than once.
- If the question can be decomposed into multiple sub-questions, suggest all of them.
- If multipple tool calls can be used at once to answer the question, suggest all of them.
- Do not explain your next steps in the answer, instead use tools to answer the question.
- Never use word context and refer to it as the available products.
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
- As an output you need to return the following:

* answer: The answer to the question based on your current knowledge and the tool results.
* references: The list of the indexes from the chunks returned from all tool calls that were used to answer the question. If more than one chunk was used to compile the answer from a single tool call, be sure to return all of them.
* Each reference should have an id and a short description of the item based on the retrieved context.
* final_answer: True if you have all the information needed to provide a complete answer, False otherwise.

- The answer to the question should contain detailed information about the product and should be returned with detailed specification in bullet points.
- The short description should have the name of the item.
- If the user's request requires using a tool, set tool_calls with the appropriate function names and arguments.
"""

   template = Template(prompt_template)
   
   prompt = template.render(
      available_tools=state.available_tools
   )

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=AgentResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   ai_message = format_ai_message(response)

   return {
      "messages": [ai_message],
      "tool_calls": response.tool_calls,
      "iteration": state.iteration + 1,
      "answer": response.answer,
      "final_answer": response.final_answer,
      "references": response.references
   }

# %% [markdown]
# #### Tool Router Edge

# %%
def tool_router(state: State) -> str:
    """Decide whether to continue or end"""
    
    if state.final_answer:
        return "end"
    elif state.iteration > 2:
        return "end"
    elif len(state.tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# #### Intent Router

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str

# %%
@traceable(
    name="intent_router_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def intent_router_node(state: State):

   prompt_template =  """You are part of a shopping assistant that can answer questions about products in stock.

Instructions:
- You will be given a question and you need to clasify it into relevant or not relevant.
- If the question is not relevant, return False in field "question_relevant" and set "answer" to explanation why it is not relevant.
- If the question is relevant, return True in field "question_relevant" and set "answer" to "".
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
"""

   template = Template(prompt_template)
   
   prompt = template.render()

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=IntentRouterResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   return {
      "question_relevant": response.question_relevant,
      "answer": response.answer
      }

# %%
def intent_router_conditional_edges(state: State):

    if state.question_relevant:
        return "agent_node"
    else:
        return "end"

# %% [markdown]
# ### Graph

# %%
workflow = StateGraph(State)

tools = [get_formatted_context]
tool_node = ToolNode(tools)
tool_descriptions = get_tool_descriptions(tools)

workflow.add_node("agent_node", agent_node)
workflow.add_node("tool_node", tool_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "agent_node": "agent_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "agent_node",
    tool_router,
    {
        "tools": "tool_node",
        "end": END
    }
)

workflow.add_edge("tool_node", "agent_node")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Persistent State

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# #### Set up the database (once)

# %%
import os

with PostgresSaver.from_conn_string(f"postgresql://{os.getenv('POSTGRES_USER')}:{os.getenv('POSTGRES_PASSWORD')}@localhost:{os.getenv('POSTGRES_PORT')}/{os.getenv('POSTGRES_DB')}") as checkpointer:

    checkpointer.setup()

# %% [markdown]
# #### Multiturn Conversation

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000005"
    }
}

with PostgresSaver.from_conn_string(f"postgresql://{os.getenv('POSTGRES_USER')}:{os.getenv('POSTGRES_PASSWORD')}@localhost:{os.getenv('POSTGRES_PORT')}/{os.getenv('POSTGRES_DB')}") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    answer_1 = graph.invoke(initial_state, config)

# %%
answer_1
# Out:
# {'messages': [{'role': 'user',
#    'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'},
#   AIMessage(content='I will check the available earphones, laptop bags, and cool items for kids in the inventory for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]),
#   ToolMessage(content="- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you with better after-sales service)\n- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0BTD88265, rating: 4.6, description: HeGaalah Open Ear Bone Conduction Headphones True Air Conduction Bluetooth 5.3 Wireless Bluetooth with Digital Display Charging,IPX7 Waterproof Earphones Sport, Clip-on Earphones b\n- ID: B0BF98MTY9, rating: 4.1, description: Lanyard Compatible with AirPods Pro 2, New Earbuds Lanyard Wireless Bluetooth Headphones Cover Anti-Drop Rope Lanyard Suitable for AirPods Pro 2 (Fluorescent) High quality materials: Consists of braided PPM (polypropylene), the tape does not absorb moisture and is weatherproof. The mobile phone chain is very light and very difficult to pick up dirt, perfect for outdoor activities. Noctilucent rope, the premise is t ...
#   ToolMessage(content='- ID: B0B5H7T7XZ, rating: 4.5, description: Laptop Bag 15.6 Inch, Laptop Briefcase Messenger Bag Carrying Case for Work, Laptop Case Sleeve Computer Bag for Men Women Leather,Mesh Imported Multi-pockets and Large Capacity: This 15.6 inch laptop bag for men and women provides multiple independent spaces to keep your every item secure and well-organized. 1 x Front zipper pocket with key chain, 1 x Main compartment for laptop, 3 x RFID ID cards pouches, 1 x Middle built-in zipper pocket, 2 x mesh pocket, 4 x pen holder. And the document compartment easily places your files, magazines and books. Lightweight & Convenient: The laptop carrying bag is equipped with a leather handle and a removable shoulder strap. can be used as a laptop carrying case, shoulder bag, tote bag or sleeve base on your needs. The luggage strap on the back can easily fix the laptop carrying case on the trolley of the suitcase, which makes your journey more convenient. Protective Computer Bag for Laptops: 15.6 laptop bag interior is designed with a shock-absorbing soft lining to avoid accidental collision damage to the computer, reduce the cushioning force, and effectively protect your laptop and other valuables. Fashion design: This slim and portable briefcases for men is suitable for daily use, can hold a lot of equipment without being bloated. The laptop carrying case fits most kinds of environments, perfect for your daily work, business travel, weekend getaway or school life. Dimensions: 16"L x 11.4"H x 2.4"W; weight: 1.14 lbs, Main laptop compartment of laptop briefcase compatible with hp, lenovo, Microsoft surface, dell and macbook laptops or tablets smaller than 15.6 inches.\n- ID: B07F9MFVKS, rating: 4.7, description: EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger B
\n- Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, water-resistant canvas with PU leather, multiple pockets, and stylish design.\n\nFor something cool for kids, options include:\n- QearFun Dinosaur Headphones for Boys Kids: Wired headphones with microphone, noise cancelling, adjustable headband, and fun dinosaur design.\n- Various sticker packs (Snoopy, Animal, Graffiti, Disney Princess) that are waterproof, colorful, and great for decorating personal items.\n\nIf you want detailed specifications or to purchase any of these, please let me know!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'question_relevant': True,
#  'iteration': 2,
#  'answer': 'For earphones, there are several options:\n- Empsun Wired Earbuds Headphones with Microphone: Comfortable in-ear design with stereo bass, noise isolation, and compatibility with devices having a 3.5 mm interface.\n- HeGaalah Open Ear Bone Conduction Headphones: Wireless Bluetooth 5.3 with digital display charging, IPX7 waterproof, suitable for sports.\n- CASCHO Wireless Earbuds V5.3: Bluetooth earbuds with 37 hours playtime, CVC8.0 clear call, deep bass, and IPX7 waterproof.\n\nFor a laptop bag for your wife, here are some options:\n- Laptop Bag 15.6 Inch: Leather, multi-pockets, large capacity, shock-absorbing soft lining, lightweight, and convenient with a luggage strap.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag: Waterproof, shockproof, made of high-quality canvas with a unique pattern.\n- KIZUNA Laptop Bag Case 14 Inch: Water-resistant briefcase with ultra-thick cushioning for protection, compatible with various laptop models.\n- DOMISO 17.3 inch Laptop Sleeve Case: Water-resistant, shockproof, with extra storage space for accessories.\n- Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, water-resistant canvas with PU leather, multiple pockets, and stylish design.\n\nFor something cool for kids, options include:\n- QearFun Dinosaur Headphones for Boys Kids: Wired headphones with microphone, noise cancelling, adjustable headband, and fun dinosaur design.\n- Various sticker packs (Snoopy, Animal, Graffiti, Disney Princess) that are waterproof, colorful, and great for decorating personal items.\n\nIf you want detailed specifications or to purchase any of these, please let me know!',
#  'available_tools': [{'name': 'get_formatted_context',
#    'description': 'Get the top k context, each representing an inventory item for a given query.',
#    'parameters': {'type': 'object',
#     'properties': {'query': {'type': 'string',
#       'description': 'The query to get the top k context for'},
#      'top_k': {'type': 'integer',
#       'description': 'The number of context chunks to retrieve, works best with 5 or more',
#       'default': 5}}},
#    'required': ['query'],
#    'returns': {'type': 'string',
#     'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}],
#  'tool_calls': [],
#  'final_answer': True,
#  'references': [RAGUsedContext(id='B09VB5M3L5', description='Empsun Wired Earbuds Headphones with Microphone'),
#   RAGUsedContext(id='B0BTD88265', description='HeGaalah Open Ear Bone Conduction Headphones'),
#   RAGUsedContext(id='B0BLJXPRL9', description='CASCHO Ear Buds Wireless Earbuds V5.3'),
#   RAGUsedContext(id='B0B5H7T7XZ', description='Laptop Bag 15.6 Inch'),
#   RAGUsedContext(id='B07F9MFVKS', description='EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag'),
#   RAGUsedContext(id='B0B62LR2YT', description='KIZUNA Laptop Bag Case 14 Inch'),
#   RAGUsedContext(id='B0C2C87FW3', description='DOMISO 17.3 inch Laptop Sleeve Case'),
#   RAGUsedContext(id='B0BSGDCVND', description='Missnine Tote Bag Canvas Laptop Bag 15.6 inch'),
#   RAGUsedContext(id='B0B67M9C9P', description='QearFun Dinosaur Headphones for Boys Kids'),
#   RAGUsedContext(id='B09X5HVNFL', description='Your Store 100PCS Snoopy Stickers'),
#   RAGUsedContext(id='B0C3V6WD2X', description='Animal Stickers 200 PCS Cute Waterproof Water Bottle Stickers'),
#   RAGUsedContext(id='B09XN72MP6', description='100PCS Graffiti Stickers Pack for Skateboard'),
#   RAGUsedContext(id='B0BTKWY6XG', description='100Pcs Kids Disney Stickers Pack Princess Stickers')]}

# %%
print(answer_1["answer"])
# Out:
# For earphones, there are several options:
# - Empsun Wired Earbuds Headphones with Microphone: Comfortable in-ear design with stereo bass, noise isolation, and compatibility with devices having a 3.5 mm interface.
# - HeGaalah Open Ear Bone Conduction Headphones: Wireless Bluetooth 5.3 with digital display charging, IPX7 waterproof, suitable for sports.
# - CASCHO Wireless Earbuds V5.3: Bluetooth earbuds with 37 hours playtime, CVC8.0 clear call, deep bass, and IPX7 waterproof.
#
# For a laptop bag for your wife, here are some options:
# - Laptop Bag 15.6 Inch: Leather, multi-pockets, large capacity, shock-absorbing soft lining, lightweight, and convenient with a luggage strap.
# - EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag: Waterproof, shockproof, made of high-quality canvas with a unique pattern.
# - KIZUNA Laptop Bag Case 14 Inch: Water-resistant briefcase with ultra-thick cushioning for protection, compatible with various laptop models.
# - DOMISO 17.3 inch Laptop Sleeve Case: Water-resistant, shockproof, with extra storage space for accessories.
# - Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, water-resistant canvas with PU leather, multiple pockets, and stylish design.
#
# For something cool for kids, options include:
# - QearFun Dinosaur Headphones for Boys Kids: Wired headphones with microphone, noise cancelling, adjustable headband, and fun dinosaur design.
# - Various sticker packs (Snoopy, Animal, Graffiti, Disney Princess) that are waterproof, colorful, and great for decorating personal items.
#
# If you want detailed specifications or to purchase any of these, please let me know!

# %% [markdown]
# ### State Streaming

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000006"
    }
}

with PostgresSaver.from_conn_string(f"postgresql://{os.getenv('POSTGRES_USER')}:{os.getenv('POSTGRES_PASSWORD')}@localhost:{os.getenv('POSTGRES_PORT')}/{os.getenv('POSTGRES_DB')}") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates"]
    ):
        print(chunk)
# Out:
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': 'Could you please specify the type of earphones, laptop bag, and what kind of cool items you are looking for your kids? This will help me find the best products in stock for you.'}})
# ('updates', {'agent_node': {'messages': [AIMessage(content='I will look for earphones, laptop bags, and cool items for kids in the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 3}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 3}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 3}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 3}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 3}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 3})], 'iteration': 1, 'answer': 'I will look for earphones, laptop bags, and cool items for kids in the available products for you.', 'final_answer': False, 'references': []}})
# ('updates', {'tool_node': {'messages': [ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you with better after-sales service)\n- ID: B0BTD88265, rating: 4.6, description: HeGaalah Open Ear Bone Conduction Headphones True Air Conduction Bluetooth 5.3 Wireless Bluetooth with Digital Display Charging,IPX7 Waterproof Earphones Sport, Clip-on Earphones b\n", name='get_formatted_context', tool_call_id='call_0'), ToolMessage(content='- ID: B0B5H7T7XZ, rating: 4.5, description: Laptop Bag 15.6 Inch, Laptop Briefcase Messenger Bag Carrying Case for Work, Laptop Case Sleeve Computer Bag for Men Women Leather,Mesh Imported Multi-pockets and Large Capacity: This 15.6 inch laptop bag for men and women provides multiple independent spaces to keep your every item secure and well-or ...
# ('updates', {'agent_node': {'messages': [AIMessage(content='Here are the products I found for you:\n\nEarphones:\n- Empsun Wired Earbuds Headphones with Microphone, Stereo Bass, Noise Isolation, 3.5 mm Interface, compatible with smartphones, tablets, and MP3 players. Comfortable ergonomic design, balanced tonal adjustment with deep bass, and 12-month hassle-free protection.\n- HeGaalah Open Ear Bone Conduction Wireless Bluetooth 5.3 Headphones, IPX7 waterproof, sport clip-on earphones with digital display charging.\n\nLaptop Bags:\n- Laptop Bag 15.6 Inch, leather messenger briefcase with multiple pockets including RFID card pouches, shock-absorbing soft lining for protection, lightweight, and suitable for laptops up to 15.6 inches. Dimensions: 16"L x 11.4"H x 2.4"W.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag, made of high-quality canvas with rebound bubble protection, waterproof and shockproof.\n- KIZUNA Laptop Bag Case 14 Inch, water-resistant briefcase with ultra-thick cushioning protection, suitable for various 14" laptops including MacBook Pro 2023.\n\nCool Items for Kids:\n- QearFun Dinosaur Headphones for Boys, wired headphones with microphone, volume limited for hearing protection, adjustable headband, and soft ear pads. Suitable for kids aged 3-16.\n- Your Store 100PCS Snoopy Stickers, cute vinyl stickers for decorating water bottles, laptops, cars, and more.\n- Animal Stickers, 200 PCS cute waterproof vinyl stickers for laptops, phones, skateboards, and other items.\n\nPlease let me know if you want more details or want to purchase any of these items.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'tool_calls': [], 'iteration': 2, 'answer': 'Here are the products I found for you:\n\nEarphones:\n- Empsun Wired Earbuds Headphones with Microphone, Stereo Bass, Noise Isolation, 3.5 mm Interface, compatible with smartphones, tablets, and MP3 players. Comfortable ergonomic design, balanced tonal adjustment with deep bass, and 12-month hassle-free protection.\n- HeGaalah Open Ear Bone Conduction Wireless Bluetooth 5.3 Headphones, IPX7 waterproof, sport clip-on earphones with digital display charging.\n\nLaptop Bags:\n- Laptop Bag 15.6 Inch, leather messenger briefcase with multiple pockets including RFID card pouches, shock-absorbing soft lining for protection, lightweight, and suitable for laptops up to 15.6 inches. Dimensions: 16"L x 11.4"H x 2.4"W.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag, made of high-quality canvas with rebound bubble protection, waterproof and shockproof.\n- KIZUNA Laptop Bag Case 14 Inch, water-resistant briefcase with ultra-thick cushioning protection, suitable for various 14" laptops including MacBook Pro 2023.\n\nCool Items for Kids:\n- QearFun Dinosaur Headphones for Boys, wired headphones with microphone, volume limited for hearing protection, adjustable headband, and soft ear pads. Suitable for kids aged 3-16.\n- Your Store 100PCS Snoopy Stickers, cute vinyl stickers for decorating water bottles, laptops, cars, and more.\n- Animal Stickers, 200 PCS cute waterproof vinyl stickers for laptops, phones, skateboards, and other items.\n\nPlease let me know if you want more details or want to purchase any of these items.', 'final_answer': True, 'references': [RAGUsedContext(id='B09VB5M3L5', description='Empsun Wired Earbuds Headphones'), RAGUsedContext(id='B0BTD88265', description='HeGaalah Open Ear Bone Conduction Headphones'), RAGUsedContext(id='B0B5H7T7XZ', description='Laptop Bag 15.6 Inch Leather Messenger Briefcase'), RAGUsedContext(id='B07F9MFVKS', description='EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag'), RAGUsedContext(id='B0B62LR2YT', description='KIZUNA Laptop Bag Case 14 Inch Water Resistant Briefcase'), RAGUsedContext(id='B0B67M9C9P', description='QearFun Dinosaur Headphones for Boys Kids'), RAGUsedContext(id='B09X5HVNFL', description='Your Store 100PCS Snoopy Stickers'), RAGUse ...

# %%
connection_string = f"postgresql://{os.getenv('POSTGRES_USER')}:{os.getenv('POSTGRES_PASSWORD')}@localhost:{os.getenv('POSTGRES_PORT')}/{os.getenv('POSTGRES_DB')}"

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000007"
    }
}

with PostgresSaver.from_conn_string(connection_string) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates", "debug"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': -1, 'timestamp': '2026-02-10T17:39:30.133962+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-40a0-6fa4-bfff-945a3b68b2b7'}}, 'parent_config': None, 'values': {'messages': [], 'references': []}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': '554fb1c6-f2e3-e327-ea9c-a2ea42c28c30', 'name': '__start__', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 0, 'timestamp': '2026-02-10T17:39:30.135437+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-40a8-6498-8000-65df4e91848c'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-40a0-6fa4-bfff-945a3b68b2b7'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['intent_router_node'], 'tasks': [{'id': '4f87bd3f-34de-a9de-f98c-63178702ac90', 'name': 'intent_router_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 1, 'timestamp': '2026-02-10T17:39:30.135450+00:00', 'type': 'task', 'payload': {'id': '4f87bd3f-34de-a9de-f98c-63178702ac90', 'name': 'intent_router_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], question_relevant=False, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:intent_router_node',)}})
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': 'You are asking about earphones, a laptop bag, and something cool for kids. Please specify the type of products or categories you are interested in for your kids so I can assist you better with the available products.'}})
# ('debug', {'step': 1, 'timestamp': '2026-02-10T17:39:32.327700+00:00', 'type': 'task_result', 'payload': {'id': '4f87bd3f-34de-a9de-f98c-63178702ac90', 'name': 'intent_router_node', 'error': None, 'result': {'question_relevant': True, 'answer': 'You are asking about earphones, a laptop bag, and something cool for kids. Please specify the type of products or categories you are interested in for your kids so I can assist you better with the available products.'}, 'interrupts': []}})
# ('debug', {'step': 1, 'timestamp': '2026-02-10T17:39:32.328153+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-5592-67a0-8001-35b0ef43734b'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-40a8-6498-8000-65df4e91848c'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'question_relevant': True, 'answer': 'You are asking about earphones, a laptop bag, and something cool for kids. Please specify the type of products or categories you are interested in for your kids so I can assist you better with the available products.', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 1, 'parents': {}}, 'next': ['agent_node'], 'tasks': [{'id': 'ba1be6a5-c517-0ed6-4d06-ff4ba7c952e5', 'name': 'agent_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 2, 'timestamp': '2026-02-10T17:39:32.328172+00:00', 'type': 'task', 'payload': {'id': 'ba1be6a5-c517-0ed6-4d06-ff4ba7c952e5', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], question_relevant=True, iteration=0, answer='You are asking about earphones, a laptop bag, and something cool for kids. Please specify the type of products or categories you are interested in for your kids so I can assist you better with the available products.', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:agent_node',)}})
# ('updates', {'agent_node': {'messages': [AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', 'final_answer': False, 'references': []}})
# ('debug', {'step': 2, 'timestamp': '2026-02-10T17:39:34.506968+00:00', 'type': 'task_result', 'payload': {'id': 'ba1be6a5-c517-0ed6-4d06-ff4ba7c952e5', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', 'final_answer': False, 'references': []}, 'interrupts': []}})
# ('debug', {'step': 2, 'timestamp': '2026-02-10T17:39:34.507624+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-6a5b-6056-8002-c0ff87f06a31'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-5592-67a0-8001-35b0ef43734b'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'question_relevant': True, 'iteration': 1, 'answer': 'I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'final_answer': False, 'references': []}, 'metadata': {'source': 'loop', 'step': 2, 'parents': {}}, 'next': ['tool_node'], 'tasks': [{'id': '453cb433-39fa-9dc9-ef2e-7e5707bcabe9', 'name': 'tool_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 3, 'timestamp': '2026-02-10T17:39:34.507641+00:00', 'type': 'task', 'payload': {'id': '453cb433-39fa-9dc9-ef2e-7e5707bcabe9', 'name': 'tool_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], question_relevant=True, iteration=1, answer='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], final_answer=False, references=[]), 'triggers': ('branch:to:tool_node',)}})
# ('updates', {'tool_node': {'messages': [ToolMessage(content="- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you with better after-sales service)\n- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0BTD88265, rating: 4.6, description: HeGaalah Open Ear Bone Conduction Headphones True Air Conduction Bluetooth 5.3 Wireless Bluetooth with Digital Display Charging,IPX7 Waterproof Earphones Sport, Clip-on Earphones b\n- ID: B0BF98MTY9, rating: 4.1, description: Lanyard Compatible with AirPods Pro 2, New Earbuds Lanyard Wireless Bluetooth Headphones Cover Anti-Drop Rope Lanyard Suitable for AirPods Pro 2 (Fluorescent) High quality materials: Consists of braided PPM (polypropylene), the tape does not absorb moisture and is weatherproof. The mobile phone chain is very light and very difficult to pick up dirt, perfect for outdoor activiti ...
# ('debug', {'step': 3, 'timestamp': '2026-02-10T17:39:35.300117+00:00', 'type': 'task_result', 'payload': {'id': '453cb433-39fa-9dc9-ef2e-7e5707bcabe9', 'name': 'tool_node', 'error': None, 'result': {'messages': [ToolMessage(content="- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you with better after-sales service)\n- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0BTD88265, rating: 4.6, description: HeGaalah Open Ear Bone Conduction Headphones True Air Conduction Bluetooth 5.3 Wireless Bluetooth with Digital Display Charging,IPX7 Waterproof Earphones Sport, Clip-on Earphones b\n- ID: B0BF98MTY9, rating: 4.1, description: Lanyard Compatible with AirPods Pro 2, New Earbuds Lanyard Wireless Bluetooth Headphones Cover Anti-Drop Rope Lanyard Suitable for AirPods Pro 2 (Fluorescent) High quality materials: Consists of braided PPM ( ...
# ('debug', {'step': 3, 'timestamp': '2026-02-10T17:39:35.300290+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77
\n- Empsun Wired Earbuds Headphones with Microphone: Comfortable in-ear design, stereo bass, noise isolation, compatible with all smartphones and devices with 3.5 mm interface.\n- CASCHO Wireless Earbuds V5.3: 37 hours playtime, Bluetooth, IPX7 waterproof, deep bass, LED display on charging case.\n- HeGaalah Open Ear Bone Conduction Headphones: Bluetooth 5.3, waterproof, clip-on style.\n- QearFun Dinosaur Headphones for Kids (also suitable for kids): Wired headphones with microphone, volume limited for safety, adjustable headband, cute dinosaur design.\n\nLaptop bags for your wife:\n- Laptop Bag 15.6 Inch: Leather, multi-pockets, lightweight, shock-absorbing soft lining, suitable for laptops up to 15.6 inches.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag: Waterproof, shockproof, canvas material with metal zipper and buckle.\n- KIZUNA Laptop Bag Case 14 Inch: Water-resistant, shoulder sleeve briefcase, ultra-thick protective cushioning, compatible with various 14-15 inch laptops.\n- DOMISO 17.3 inch Laptop Sleeve Case: Water-resistant, shockproof, with extra storage space.\n- Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, multiple pockets, water-resistant canvas with PU leather, stylish and practical.\n\nSomething cool for your kids:\n- QearFun Dinosaur Headphones for Boys Kids: Cute dinosaur design, noise cancelling, built-in microphone, comfortable and adjustable.\n- Various sticker packs (Snoopy, Animal, Graffiti, Disney Princess): Waterproof, colorful, great for decorating laptops, water bottles, skateboards, and more.\n\nIf you want detailed specifications or want to choose one or more from these options, please let me know!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'tool_calls': [], 'iteration': 2, 'answer': 'Here are some options for your requests:\n\nEarphones for you:\n- Empsun Wired Earbuds Headphones with Microphone: Comfortable in-ear design, stereo bass, noise isolation, compatible with all smartphones and devices with 3.5 mm interface.\n- CASCHO Wireless Earbuds V5.3: 37 hours playtime, Bluetooth, IPX7 waterproof, deep bass, LED display on charging case.\n- HeGaalah Open Ear Bone Conduction Headphones: Bluetooth 5.3, waterproof, clip-on style.\n- QearFun Dinosaur Headphones for Kids (also suitable for kids): Wired headphones with microphone, volume limited for safety, adjustable headband, cute dinosaur design.\n\nLaptop bags for your wife:\n- Laptop Bag 15.6 Inch: Leather, multi-pockets, lightweight, shock-absorbing soft lining, suitable for laptops up to 15.6 inches.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag: Waterproof, shockproof, canvas material with metal zipper and buckle.\n- KIZUNA Laptop Bag Case 14 Inch: Water-resistant, shoulder sleeve briefcase, ultra-thick protective cushioning, compatible with various 14-15 inch laptops.\n- DOMISO 17.3 inch Laptop Sleeve Case: Water-resistant, shockproof, with extra storage space.\n- Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, multiple pockets, water-resistant canvas with PU leather, stylish and practical.\n\nSomething cool for your kids:\n- QearFun Dinosaur Headphones for Boys Kids: Cute dinosaur design, noise cancelling, built-in microphone, comfortable and adjustable.\n- Various sticker packs (Snoopy, Animal, Graffiti, Disney Princess): Waterproof, colorful, great for decorating laptops, water bottles, skateboards, and more.\n\nIf you want detailed specifications or want to choose one or more from these options, please let me know!', 'final_answer': True, 'references': [RAGUsedContext(id='B09VB5M3L5', description='Empsun Wired Earbuds Headphones with  ...
# ('debug', {'step': 4, 'timestamp': '2026-02-10T17:39:48.050457+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-eb83-66d8-8004-c8944e22168b'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f106a77-71eb-62b2-8003-a4b425b6c961'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you with better after-sales service)\n- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tona ...

# %%
def process_graph_event(chunk):

    def _is_node_start(chunk):
        return chunk[1].get("type") == "task"

    def _is_node_end(chunk):
        return chunk[0] == "updates"

    def _tool_to_text(tool_call):
        if tool_call.name == "get_formatted_context":
            return f"Looking for items: {tool_call.arguments.get('query', '')}."
        elif tool_call.name == "get_formatted_reviews_context":
            return f"Fetching user reviews..."

    if _is_node_start(chunk):
        if chunk[1].get("payload", {}).get("name") == "intent_router_node":
            print("Analysing the question...")
        if chunk[1].get("payload", {}).get("name") == "agent_node":
            print("Planning...")
        if chunk[1].get("payload", {}).get("name") == "tool_node":
            message = " ".join([_tool_to_text(tool_call) for tool_call in chunk[1].get('payload', {}).get('input', {}).tool_calls])
            print(message)

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000008"
    }
}

with PostgresSaver.from_conn_string(connection_string) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates", "debug"]
    ):
        process_graph_event(chunk)
# Out:
# Analysing the question...
# Planning...
# Looking for items: earphones. Looking for items: laptop bag. Looking for items: cool kids items.
# Planning...

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000008"
    }
}

with PostgresSaver.from_conn_string(connection_string) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates", "debug", "values"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': 5, 'timestamp': '2026-02-10T17:43:46.932758+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000008', 'checkpoint_id': '1f106a80-d1a8-66ba-8005-c6cc4f210ed4'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000008', 'checkpoint_id': '1f106a7f-b1e3-6aec-8004-73e4c9174764'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the s ...
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you  ...
# ('debug', {'step': 6, 'timestamp': '2026-02-10T17:43:46.935859+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000008', 'checkpoint_id': '1f106a80-d1b3-6722-8006-ab3b7cb0afab'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000008', 'checkpoint_id': '1f106a80-d1a8-66ba-8005-c6cc4f210ed4'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the s ...
# ('debug', {'step': 7, 'timestamp': '2026-02-10T17:43:46.935867+00:00', 'type': 'task', 'payload': {'id': '2248a4b5-92c0-21b1-5285-1840e6127997', 'name': 'intent_router_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, micro ...
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': ''}})
# ('debug', {'step': 7, 'timestamp': '2026-02-10T17:43:48.252584+00:00', 'type': 'task_result', 'payload': {'id': '2248a4b5-92c0-21b1-5285-1840e6127997', 'name': 'intent_router_node', 'error': None, 'result': {'question_relevant': True, 'answer': ''}, 'interrupts': []}})
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, camera, laptop, etc. Compatible with cleaning most bluetooth earphones, TWS on the market (If you have any questions, you can contact us by Amazon mail, to provide you  ...
# ('debug', {'step': 7, 'timestamp': '2026-02-10T17:43:48.252977+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000008', 'checkpoint_id': '1f106a80-de43-60e6-8007-643e1e34a839'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000008', 'checkpoint_id': '1f106a80-d1b3-6722-8006-ab3b7cb0afab'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the s ...
# ('debug', {'step': 8, 'timestamp': '2026-02-10T17:43:48.252991+00:00', 'type': 'task', 'payload': {'id': 'bbfecc10-4aa9-5239-6db1-bb209c6e90c4', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content="- ID: B09VB5M3L5, rating: 4.3, description: Empsun Wired Earbuds Headphones with Microphone Stereo Bass Earphones Noise Isolation in-Ear Headset Compatible with All Smartphones Tablets iPod IPad MP3 Player That with 3.5 mm Interface(Black) . [In-line microphone]: With in-line microphone can conveninet to make calls,end calls play/pause/answer and skipping tracks forward and back. The In-ear headphone with microphone support a wide range of devices like cell phones, computers, laptops, MP3, MP4 players which with 3.5mm audio jack devices for gym, listening to music and games. Note that:the In-ear headphone with microphone don't have volume control. . [ Comfortable Design]: Comfortable in-ear and ergonomic design don’t cause any burden to your ears,they can reduce the clunky feel of earphone and increase the comfort of wearing them, comfortable in- ear headphones with a great seal which minimize outside noise so you can hear the beats clearly. . [In-ear stereo bass audio Design]: Balanced tonal adjustment with deep bass and excellent stereo sound that let you have a better listening experience,earbuds are perfect for daily use. . [Wide Compatibility]: In-ear headphones compatible with iPod, iPhone, iPad, Android smartphones , tablets, mp3 players music speaker and others devices that with a standard 3.5mm audio jack. . [Supporting]: 12-month Hassle-Free-Protection ,it is very easy to reach customer service\n- ID: B0B7495RL6, rating: 4.3, description: Cleaner Kit for AirPods Pro, 4 in 1 Earbuds Cleaning Pen, Bluetooth Headphone Cleaning Pen for Airpods, Airpods Pro 1 2 3 and Other Earphones, Keyboard, Mouse, Cellphones, Laptop, Camera (White) 【4-IN-1 DESIGN】The airpod cleaning kit is divided into 4 parts - flocking sponge, high-density brush, long-bristle brush and metal tip, which can deeply clean the earbuds and earphone charging compartment at different angles, making your earphones like new 【MULTIFUNCTIONAL CLEANING KIT】The metal tip can precisely remove the dirt in the sound hole of the earbuds, and the high-density brush under the cleaning pen tip is used to clean the fine dust. There are also flocking sponge ends and long-bristle brush ends, the earphone charging compartment can also be well cleaned, and the long-bristle end is suitable for cleaning computer peripherals such as keyboards (When replacing the flocking sponge and long-bristle brush, please rotate and pull out out) 【SAFE AND HEALTHY】 The brush end is made of environmentally friendly and soft materials, which will not damage the earbuds. Frequent cleaning of the earphones and keeping the earbuds clean can effectively improve the wearing experience and make the earphones more comfortable to wear for a long time 【PORTABLE】Segmented pen cover design, multiple functions in one, the airpods pro cleaner kit is small in size and light in weight, only the size of a pen, it can be easily put into a pocket, easy to store and carry out 【UNIVERSAL】This cleaning pen can not only clean the earphones, but also the earphone charging case, mobile phone, keyboard, mouse, microphone, c ...
# ('updates', {'agent_node': {'messages': [AIMessage(content='Here are some great options for you:\n\nEarphones for yourself:\n- Empsun Wired Earbuds Headphones with Microphone: Comfortable in-ear design, noise isolation, compatible with all smartphones and devices with 3.5mm jack, stereo bass sound, in-line microphone for calls and music control.\n- HeGaalah Open Ear Bone Conduction Headphones: Wireless Bluetooth 5.3, waterproof, clip-on design, suitable for sports.\n- CASCHO Wireless Earbuds: Bluetooth V5.3, 37 hours playtime, deep bass, IPX7 waterproof, clear call quality, comfortable fit.\n\nLaptop bag for your wife:\n- Laptop Bag 15.6 Inch: Multi-pocket, leather handle, removable shoulder strap, shock-absorbing lining, fits laptops up to 15.6 inches.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag: Waterproof, shockproof, lightweight canvas with metal zipper and buckle.\n- KIZUNA Laptop Bag Case 14 Inch: Water-resistant, protective cushioning, fits various 14" laptops, multiple carrying styles.\n- DOMISO 17.3 inch Laptop Sleeve Case: Water-resistant, shockproof, extra storage pockets, fits up to 17.3" laptops.\n- Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, water-resistant canvas with PU leather, multiple pockets, stylish and practical for women.\n\nSomething cool for your kids:\n- QearFun Dinosaur Headphones for Boys Kids: Wired headphones with microphone, adjustable headband, noise cancelling, cute dinosaur design, safe volume limit.\n- Various Sticker Packs: Cute and cool waterproof vinyl stickers featuring Snoopy, animals, graffiti, Disney princesses, perfect for decorating laptops, water bottles, skateboards, and more.\n\nIf you want more details or help with ordering, feel free to ask!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'tool_calls': [], 'iteration': 3, 'answer': 'Here are some great options for you:\n\nEarphones for yourself:\n- Empsun Wired Earbuds Headphones with Microphone: Comfortable in-ear design, noise isolation, compatible with all smartphones and devices with 3.5mm jack, stereo bass sound, in-line microphone for calls and music control.\n- HeGaalah Open Ear Bone Conduction Headphones: Wireless Bluetooth 5.3, waterproof, clip-on design, suitable for sports.\n- CASCHO Wireless Earbuds: Bluetooth V5.3, 37 hours playtime, deep bass, IPX7 waterproof, clear call quality, comfortable fit.\n\nLaptop bag for your wife:\n- Laptop Bag 15.6 Inch: Multi-pocket, leather handle, removable shoulder strap, shock-absorbing lining, fits laptops up to 15.6 inches.\n- EZrelia Pattern 15 inch Waterproof Laptop Shoulder Messenger Bag: Waterproof, shockproof, lightweight canvas with metal zipper and buckle.\n- KIZUNA Laptop Bag Case 14 Inch: Water-resistant, protective cushioning, fits various 14" laptops, multiple carrying styles.\n- DOMISO 17.3 inch Laptop Sleeve Case: Water-resistant, shockproof, extra storage pockets, fits up to 17.3" laptops.\n- Missnine Tote Bag Canvas Laptop Bag 15.6 inch: Large capacity, water-resistant canvas with PU leather, multiple pockets, stylish and practical for women.\n\nSomething cool for your kids:\n- QearFun Dinosaur Headphones for Boys Kids: