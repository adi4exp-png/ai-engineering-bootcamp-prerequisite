# %% [markdown]
# ### Import Dependencies ###

# %%
from langsmith import Client

# %% [markdown]
# 019c3c1b-fe5d-7110-b4ec-4881930bc8d4

# %%
RUN_ID="019c3c1b-fe5d-7110-b4ec-4881930bc8d4"

# %%
client = Client()

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="feedback",
    score=0,
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('019c3c31-38fb-7570-9f9c-8c2dcf527cc4'), created_at=datetime.datetime(2026, 2, 8, 7, 39, 44, 764636, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 2, 8, 7, 39, 44, 764647, tzinfo=datetime.timezone.utc), run_id=UUID('019c3c1b-fe5d-7110-b4ec-4881930bc8d4'), trace_id=None, key='feedback', score=0, value=None, comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="comments",
    value="This is a long form free text feedback left by Aurimas",
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('019c3c31-aa4e-7e32-be16-2a25d1f12c98'), created_at=datetime.datetime(2026, 2, 8, 7, 40, 13, 774775, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 2, 8, 7, 40, 13, 774781, tzinfo=datetime.timezone.utc), run_id=UUID('019c3c1b-fe5d-7110-b4ec-4881930bc8d4'), trace_id=None, key='comments', score=None, value='This is a long form free text feedback left by Aurimas', comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="comments_with_score",
    value="This is a long form free text feedback left by Aditya",
    score=0,
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('019c3c32-219e-7f81-9079-c35e2c3fe458'), created_at=datetime.datetime(2026, 2, 8, 7, 40, 44, 320025, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 2, 8, 7, 40, 44, 320060, tzinfo=datetime.timezone.utc), run_id=UUID('019c3c1b-fe5d-7110-b4ec-4881930bc8d4'), trace_id=None, key='comments_with_score', score=0, value='This is a long form free text feedback left by Aditya', comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)
